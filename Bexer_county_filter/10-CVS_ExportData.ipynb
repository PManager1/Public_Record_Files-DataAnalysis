# %%
import pandas as pd
df = pd.DataFrame({'a': [1, 2], 'b': [3, 4]})
df
df.to_csv('output.csv', index=False)

# %%
# df.to_csv('output.csv', index=False)

# %%
# Read the excel file
dfk = pd.read_csv('KeywordsRem.csv') 

# Get the list of values
caps = dfk['Keywords'].tolist()

lowers = [x.lower() for x in caps]

elimkeys = caps + lowers

# df = pd.read_csv('Bay_county_FL_5.csv')
df = pd.read_csv('Bay_county_FL.csv')

df = df[df['Grantee'].str.contains('|'.join(elimkeys))==False]
# df
# from itables import show
# show(df , paging=True)

df

# df= df['Grantee'].value_counts()

# df.to_csv('output2.csv')
# Out:
#       Status                                            Grantor  \
# 6          V                                       HOYT BARBARA
# 12         V                                     STRINGER EVA L
# 22         V  HUGHES JAMES ROBERT\nSOUTHERN LIVE OAK INVESTM...
# 49         V                                HYDR PROPERTIES LLC
# 52         V                   SHEPARD DIANE L\nSHEPARD WAYNE P
# ...      ...                                                ...
# 25012      V  MOLTAN SYSTEMS INC\nMULLIGAN MARK P\nMULLIGAN ...
# 25018      V                                         RAY RAYWAT
# 25036      V                             SOUTHPORT TRIBUILD LLC
# 25101      V                 CARTER AMANDA\nOSMER LAWRENCE B JR
# 25135      V                                       DUGUE JEANIE
#
#                                                Grantee Record Date  Doc Type  \
# 6                                        DAUCH NANCY L  05/22/2023  MORTGAGE
# 12                               WILSON PROPERTIES LLC  05/22/2023  MORTGAGE
# 22                         WALLACE DENNIS\nWALLACE KAY  05/23/2023  MORTGAGE
# 49     DRY VALLEY ENTERPRISES INC\nWILLIS WILLIAM E JR  05/24/2023  MORTGAGE
# 52                           WILSON RESORT FINANCE LLC  05/24/2023  MORTGAGE
# ...                                                ...         ...       ...
# 25012                                 HENSON E DOUGLAS  02/09/2021  MORTGAGE
# 25018                            CEDAR CREEK RANCH INC  02/09/2021  MORTGAGE
# 25036                 GULF TIMBER AND LAND COMPANY INC  02/10/2021  MORTGAGE
# 25101                                  WALTERS LEON JR  02/11/2021  MORTGAGE
# 25135                       BLUE DANIEL L\nBLUE KAYE L  02/12/2021  MORTGAGE
#
#       Book Type    Book    Page  Clerk File #  \
# 6            OR  4691.0   284.0  2.023031e+09
# 12           OR  4691.0   538.0  2.023032e+09
# 22           OR  4691.0   915.0  2.023032e+09
# 49           OR  4691.0  1822.0  2.023032e+09
# 52           OR  4691.0  1877.0  2.023032e+09
# ...         ...     ...     ...           ...
# 25012        OR  4361.0  1165.0  2.021009e+09
# 25018        OR  4361.0  1354.0  2.021009e+09
# 25036        OR  4361.0  1847.0  2.021009e+09
# 25101        OR  4362.0  1533.0  2.021010e+09
# 25135        OR  4363.0   296.0  2.021010e+09
#
#                                                    Legal DocLinks
# 6                       PT L68 STAB DEV CO SEC 12-4-14\n      NaN
# 12     L 15 BLK 16 VENTURE OUT AT PANAMA CITY BEACH I...      NaN
# 22                   MISC PCLS N KEITHS BAY HARBOR ADD\n      NaN
# 49                                    MISC PCLS BAY CO\n      NaN
# 52               MISC UNITS WKS TROPICAL BREEZE RESORT\n      NaN
# ...                                                  ...      ...
# 25012                                      PCLS BAY CO\n      NaN
# 25018                                   PCL IN 27-1-14\n      NaN
# 25036                        LOTS 3-5 BLK 63 SOUTHPORT\n      NaN
# 25101                         MLTP PCL IN SEC 34 2S 13\n      NaN
# 25135           LOT 49 & PT LOT 48 BLK 33 BUNKERS COVE\n      NaN
#
# [1620 rows x 11 columns]
