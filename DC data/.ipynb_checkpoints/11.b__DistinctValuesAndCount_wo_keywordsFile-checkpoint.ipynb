# %%
import pandas as pd

# pd.set_option('display.max_columns', 10) 
pd.set_option('display.max_rows', 100)
# pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)  


df = pd.read_csv('DC_full.csv', encoding="ISO-8859-1" , low_memory=False)  # or encoding="latin1"


# Get value counts
r = df['Grantee'].value_counts()

# Save results to CSV
r.to_csv('output-dc-wo-keywords.csv', index=True)

print("Outputted results saved to 'output-dc-keywords-2.csv'")
# Out:
# Outputted results saved to 'output-dc-2.csv'
