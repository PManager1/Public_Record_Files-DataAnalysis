# %%
import pandas as pd

# pd.set_option('display.max_columns', 10) 
pd.set_option('display.max_rows', 100)
# pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)  


df = pd.read_csv('DC_full.csv', encoding="ISO-8859-1")  # or encoding="latin1"

r= df['Grantee'].value_counts()
# print(r)
r
# Out:
# HILTON RESORTS CORPORATION    413
#  LLC                          408
#  INC.                         102
#  L.P.                          90
# Hilton Resorts Corporation     79
#                              ...
# 1001 Master Tenant LLC          1
# MAYNBRIDGE CAPITAL INC.         1
# TREE LINE CAPITAL PARTNERS      1
#  CORP                           1
# CUMMINGS GRANT                  1
# Name: Grantee, Length: 8872, dtype: int64

# %%
import pandas as pd

# pd.set_option('display.max_columns', 10) 
pd.set_option('display.max_rows', 100)
# pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)  


df1 = pd.read_csv('DC_full.csv'); 


# Concatenate the DataFrames
# df = pd.concat([df1, df2,df3, df4,df5, df6,df7, df8,df9, df10,df11, df12,df13, df14,df15, df16, df10,df11, df12,df13, df14,df15, df16, df17,df18, df19,df20, df21,df22, df23, df24,df25, df26,df27, df28,df29, df30, df31,df32, df33,df34,df35, df36])

df = pd.concat([df1])
# Print the DataFrame
# print(df)



# df = pd.read_csv(["file1.csv", "file2.csv"])

r= df['Grantee'].value_counts()
# print(r)
# r

# r.to_csv('output1.csv', index=False)
r.to_csv('output2.csv')
