# %%
# Out:
# ['BANK',
#  'Credit Union',
#  'MORTGAGE',
#  'WYNDHAM VACATION RESORTS INC',
#  'VETERANS AFFAIRS',
#  'BOARD',
#  'CITY OF PANAMA CITY',
#  'SECRETARY OF HOUSING AND URBAN DEVELOPMENT',
#  'BLUEGREEN VACATIONS CORPORATION',
#  'FLORIDA HOUSING FINANCE CORPORATION',
#  'HABITAT FOR HUMANITY OF BAY COUNTY FLORIDA INC',
#  'KIAVI FUNDING INC',
#  'Grantee',
#  'RURAL HOUSING SERVICE',
#  'THIRD FEDERAL SAVINGS AND LOAN ASSOCIATION OF CLEVELAND',
#  'INSURANCE',
#  'FEDERAL',
#  'navigator private capital llc',
#  'private capital',
#  'BAY COUNTY',
#  'WALKER & DUNLOP LLC',
#  'CREDIT UNION',
#  'HOUSING',
#  'WELLS FARGO',
#  'US SMALL BUSINESS ADMINISTRATION',
#  'LENDING',
#  'BBVA USA',
#  'USA BBVA',
#  'FARM CREDIT OF NORTHWEST FLORIDA',
#  'ALOHA CAPITAL LLC',
#  'SECRETARY OF VETERANS AFFAIRS',
#  'CADENCE BANK',
#  'SECRETARY OF HOUSING&URBAN DEVELOPMENT',
#  'UNITED WHOLESALE MORTGAGE LLC',
#  'BANK OF AMERICA NA',
#  'ROCKET MORTGAGE LLC',
#  'CREDIT UNION OF TEXAS',
#  'PROSPERITY BANK',
#  'EVERETT FINANCIAL INC DBA',
#  'TEXAS STATE AFFORDABLE HOUSING CORPORATION',
#  'TOWN SQUARE MORTGAGE&INVESTMENTS LLC DBA',
#  'JPMORGAN CHASE BANK NA',
#  'FROST BANK',
#  'MORTGAGE ELECTRONIC REGISTRATION SYSTEMS INC',
#  'FAIRWAY INDEPENDENT MORTGAGE CORPORATION',
#  'GUARANTEED RATE INC',
#  'CROSSCOUNTRY MORTGAGE LLC',
#  'TEXAS DEPARTMENT OF HOUSING&COMMUNITY AFFAIRS',
#  'TEXASBANK',
#  'ROCKET MORTGAGE LLC FKA',
#  'DHI MORTGAGE COMPANY LTD',
#  'WELLS FARGO BANK NA',
#  'LOANDEPOT.COM LLC',
#  'FIRST UNITED BANK&TRUST COMPANY',
#  'PNC BANK NATIONAL ASSOCIATION',
#  'CADENCE BANK',
#  'CARDINAL FINANCIAL COMPANY LIMITED PARTNERSHIP',
#  'FIRST HORIZON BANK',
#  'ORIGIN BANK',
#  'COMERICA BANK',
#  'FEDERAL HOUSING COMMISSIONER',
#  'HIGHLANDS RESIDENTIAL MORTGAGE LTD',
#  'NATIONSTAR MORTGAGE LLC DBA',
#  'LENNAR MORTGAGE LLC',
#  'CMG MORTGAGE INC DBA',
#  'TRUIST BANK',
#  'SFMC LP DBA',
#  'FIRST FINANCIAL BANK NA',
#  'ARK LA TEX FINANCIAL SERVICES LLC DBA',
#  'INTEGRITY MORTGAGE CORPORATION OF TEXAS',
#  'PROSPERITY HOME MORTGAGE LLC',
#  'PRIMELENDING',
#  'ZIONS BANCORPORATION NA DBA',
#  'GUILD MORTGAGE COMPANY LLC',
#  'MORTGAGE RESEARCH CENTER LLC DBA',
#  'CITY CREDIT UNION',
#  'BOKF NA DBA',
#  'PENNYMAC LOAN SERVICES LLC',
#  'THRIVE MORTGAGE LLC',
#  'KIAVI FUNDING INC',
#  'NAVY FEDERAL CREDIT UNION',
#  'CORNERSTONE HOME LENDING',
#  'SIMMONS BANK',
#  'INWOOD NATIONAL BANK',
#  'WILLOW BEND MORTGAGE COMPANY LLC',
#  'VERITEX COMMUNITY BANK',
#  'PROVIDENT FUNDING ASSOCIATES LP',
#  'AMERICAN AIRLINES FEDERAL CREDIT UNION',
#  'TEXAS TRUST CREDIT UNION',
#  'TRIDENT REALTY INVESTMENTS LLC',
#  'WILDCAT LENDING FUND ONE LP',
#  'RANDOLPH BROOKS FEDERAL CREDIT UNION',
#  'CITIBANK NA',
#  'CITY BANK DBA',
#  'SOUTHWEST FUNDING LP',
#  'TEXANS CREDIT UNION',
#  'FIRST NATIONAL BANK',
#  'CALIBER HOME LOANS INC',
#  'MIDFIRST BANK',
#  'SWBC MORTGAGE CORP',
#  'INDEPENDENT BANK',
#  'FIRST BANK',
#  'U S BANK NATIONAL ASSOCIATION',
#  'ASPIRE FINANCIAL INC DBA',
#  'LOWER LLC DBA',
#  'PULTE MORTGAGE LLC',
#  'DISCOVER BANK',
#  'AMCAP MORTGAGE LTD DBA',
#  'NEIGHBORHOOD LOANS INC',
#  'GATEWAY MORTGAGE',
#  'SECRETARY OF VETERANS AFFAIRS',
#  'CAPITAL FUND I LLC ISAOA',
#  'CAPITAL FUND I LLC',
#  'RFLF 7 LLC',
#  'AMERICAN NATIONAL BANK OF TEXAS',
#  'MUSTANG CREDIT SOLUTIONS LLC',
#  'PENTAGON FEDERAL CREDIT UNION',
#  'GUARDIAN MORTGAGE',
#  'INTERBANK',
#  'Grantee',
#  'AML FUNDING LLC DBA',
#  'NORTH DALLAS BANK&TRUST CO',
#  'MORGAN STANLEY PRIVATE BANK NATIONAL ASSOCIATION',
#  'EASY STREET CAPITAL INVESTMENTS LLC',
#  'PARAMOUNT RESIDENTIAL MORTGAGE GROUP INC',
#  'SYNERGY ONE LENDING INC',
#  'TEXAS SECURITY BANK',
#  'DALLAS CITY',
#  'SECURITYNATIONAL MORTGAGE COMPANY',
#  'PLAINSCAPITAL BANK',
#  'ACADEMY MORTGAGE CORPORATION',
#  'TEXAS BANK&TRUST COMPANY',
#  'AMERICAN FINANCIAL NETWORK INC',
#  'NEWREZ LLC DBA',
#  'VELOCIO MORTGAGE LLC',
#  'FIRST UNITED BANK&TRUST CO',
#  'MORTGAGE LINK INC',
#  'BOOMERANG FINANCE SUB REIT LLC',
#  'GARDNER FINANCIAL SERVICES LTD DBA',
#  'CIVIC FINANCIAL SERVICES LLC',
#  'EUSTIS MORTGAGE CORP DBA',
#  'GOODLEAP LLC',
#  'MATTAMY HOME FUNDING LLC',
#  'CARRINGTON MORTGAGE SERVICES LLC',
#  'REGIONS BANK',
#  'CHURCHILL MORTGAGE CORPORATION',
#  'TEXAS REPUBLIC BANK NA',
#  'SUSSER BANK',
#  'ORIGINPOINT LLC',
#  'UIF CORPORATION',
#  'BPL MORTGAGE TRUST LLC',
#  'BROOKHOLLOW MORTGAGE SERVICES LTD',
#  'TEXAS BRAND BANK',
#  'BRAZOS NATIONAL BANK',
#  'FREEDOM MORTGAGE CORPORATION',
#  'CERTIFIED FUNDING LP',
#  'AMCAP MORTGAGE LTD',
#  'LOAN RANGER CAPITAL INVESTMENTS REIT LLC',
#  'EECU',
#  'AMERISAVE MORTGAGE CORPORATION',
#  'BANK OF DESOTO NA',
#  'PNC BANK NA',
#  'EQUITY PRIME MORTGAGE LLC',
#  'RESOURCE ONE CREDIT UNION',
#  'NATIONS RELIABLE LENDING LLC',
#  'DOUBLE BACKFLIP LLC',
#  'GREAT WESTERN FINANCIAL SERVICES INC',
#  'GARLAND HOUSING FINANCE CORPORATION GARLAND TEXAS',
#  'CROSSTIMBERS CAPITAL INC',
#  'BANK OF ENGLAND',
#  'GUARANTEED RATE AFFINITY LLC',
#  'HOME POINT FINANCIAL CORPORATION',
#  'UMORTGAGE LLC',
#  'HOMEBRIDGE FINANCIAL SERVICES INC',
#  'PEGASUS BANK',
#  'NEXT DOOR LENDING',
#  'BETTER MORTGAGE CORPORATION ISAOA',
#  'BANK OZK',
#  'VIP MORTGAGE INC',
#  'AMWEST FUNDING CORP',
#  'SCF JAKE LP',
#  'BAY EQUITY LLC',
#  'LIMA ONE CAPITAL LLC',
#  'NETWORK FUNDING LP',
#  'DALLAS NEIGHBORHOOD HOMES',
#  'BOSSE LENDING LLC',
#  'INTERNATIONAL BANK OF COMMERCE',
#  'LENDINGONE LLC',
#  'UBS BANK USA',
#  'NUWAVE LENDING LLC',
#  'BROKER SOLUTIONS INC DBA',
#  'TOLLESON PRIVATE BANK',
#  'WINTEX GROUP LLC DBA',
#  'REGIONS BANK DBA',
#  'RFLF 4 LLC',
#  'PLANET HOME LENDING LLC',
#  'SOUTHWEST AIRLINES FEDERAL CREDIT UNION',
#  'LBK LENDING LLC',
#  'ROYAL UNITED MORTGAGE LLC',
#  'NTFN INC',
#  'PANORAMA MORTGAGE GROUP LLC DBA',
#  'AMERICAN NATIONAL BANK&TRUST',
#  'MCI PREFERRED INCOME FUND IV LLC',
#  'RLM MORTGAGE LLC DBA',
#  'NEWREZ LLC',
#  'NBKC BANK',
#  'BENCHMARK BANK',
#  'FIRST FUNDING INVESTMENTS INC',
#  'CEASONS HOLDINGS LLC',
#  'MOVEMENT MORTGAGE LLC',
#  'A&D MORTGAGE LLC',
#  'BANK OF THE WEST',
#  'CROSSFIRST BANK',
#  'NEW AMERICAN FUNDING LLC',
#  'PLAZA HOME MORTGAGE INC',
#  'CORNERSTONE HOME LENDING INC',
#  'OCMBC INC',
#  'MCI MORTGAGE INC',
#  'CENTENNIAL BANK DBA',
#  'BANK OF AMERICA',
#  'CLICK N CLOSE INC',
#  'B1BANK',
#  'M I FINANCIAL LLC',
#  'HOMEBANK TEXAS',
#  'LIFESTYLE HOME LENDING LLC',
#  'AMERICAN PACIFIC MORTGAGE CORPORATION',
#  'FLAGSTAR BANK NA',
#  'USAA FEDERAL SAVINGS BANK',
#  'ANGEL OAK MORTGAGE SOLUTIONS LLC',
#  'WELLS FARGO BANK NATIONAL ASSOCIATION',
#  'AMERICAS CREDIT UNION',
#  'CALCON MUTUAL MORTGAGE LLC DBA',
#  'ROSA ELVIN JOHN BANKERS INSURANCE DBA',
#  'ENCORE BANK',
#  'GREAT PLAINS NATIONAL BANK',
#  'EAST WEST BANK',
#  'CHERRY CREEK MORTGAGE LLC',
#  'INDEPENDENT BANK DBA',
#  'NBH BANK',
#  'CITIZENS NATIONAL BANK OF TEXAS',
#  'CHANGE LENDING LLC',
#  'IBNET CO LTD',
#  'AZBEN LIMITED LLC',
#  'CITADEL SERVICING CORPORATION DBA',
#  'MUTUAL OF OMAHA MORTGAGE INC',
#  'GENEVA FINANCIAL LLC',
#  'T2 FINANCIAL LLC DBA',
#  'GUARANTY BANK&TRUST NA',
#  'NEXBANK',
#  'UNION HOME MORTGAGE CORP',
#  'FIRSTCAPITAL BANK OF TEXAS NA',
#  'RCN CAPITAL LLC',
#  'ZILLOW HOME LOANS LLC',
#  'HOMEXPRESS MORTGAGE CORP',
#  'DALLAS MORTGAGE ASSOCIATES',
#  'LIBERTY NATIONAL BANK',
#  'TREZ CAPITAL 2015 CORPORATION',
#  'AMERICAN NEIGHBORHOOD MORTGAGE ACCEPTANCE COMPANY LLC',
#  'DIGITAL FEDERAL CREDIT UNION',
#  'CLM MORTGAGE INC',
#  'SUN WEST MORTGAGE COMPANY INC',
#  'LAKEVIEW LOAN SERVICING LLC',
#  'CATTLEMENS BANK',
#  'MORTGAGE FINANCIAL SERVICES LLC',
#  'WATERMARK CAPITAL INC',
#  'FIRST NATIONAL BANK OF OMAHA',
#  'TEXAS BANK',
#  'ALLIANCE BANK',
#  'HOMEWARD MORTGAGE LLC',
#  'PINNACLE BANK',
#  'BHOME MORTGAGE LLC',
#  'CITY BANK',
#  'TEXAS CAPITAL BANK',
#  'PRIMARY RESIDENTIAL MORTGAGE INC',
#  'TRINITY CAPITAL BANK OF TEXAS',
#  'NEXERA HOLDING LLC DBA',
#  'KIND LENDING LLC',
#  'U S A HOUSING&URBAN DEVELOPMENT',
#  'CENTENNIAL BANK',
#  'SPRING EQ LLC',
#  'BARCO LENDING LP',
#  'OFN LENDING LLC',
#  'GOLDMAN SACHS BANK USA',
#  'AMERICAN HERITAGE LENDING LLC',
#  'THIRD COAST BANK SSB',
#  'FINANCE OF AMERICA MORTGAGE LLC',
#  'PLAINS COMMERCE BANK',
#  'NEXUS SERIES B LLC',
#  'LIBERTYONE CREDIT UNION',
#  'LEGEND BANK NA',
#  'MFM FUNDING',
#  'ENCOMPASS LENDING GROUP LP',
#  'HOVNANIAN K AMERICAN MORTGAGE LLC',
#  'UMB BANK NA',
#  'AVONDALE PRIVATE LENDING LLC',
#  'LOWER LLC',
#  'DHLC MORTGAGE LLC',
#  'MORTGAGE SOLUTIONS OF COLORADO LLC',
#  'FILO MORTGAGE LLC',
#  'VELOCITY COMMERCIAL CAPITAL LLC',
#  'SUMMIT FUNDING INC',
#  'PHH MORTGAGE CORPORATION',
#  'FIRST CHOICE LENDING GROUP LP',
#  'ADVANCIAL FEDERAL CREDIT UNION',
#  'MOBILITY CREDIT UNION',
#  'HAWKEYE ONE ENTERPRISES INC',
#  'THE AMERICAN NATIONAL BANK OF TEXAS',
#  'PARK PLACE FINANCE LLC',
#  'WATERSTONE MORTGAGE CORPORATION',
#  'RLM MORTGAGE LLC',
#  'NFM INC DBA',
#  'UNIVERSITY FEDERAL CREDIT UNION',
#  'ROSA ELVIN JOHN DBA',
#  'BAY STREET M LLC',
#  'INVESTMARK MORTGAGE LLC',
#  'SECURITY SERVICE FEDERAL CREDIT UNION',
#  'NEIGHBORHOOD CREDIT UNION',
#  'LENDSURE MORTGAGE CORP',
#  'COMMERCIAL LENDER LLC',
#  'ENNIS STATE BANK',
#  'SFR MANAGING BORROWER LLC',
#  'VERNON OAKS CAPITAL FUNDING LLC DBA',
#  'OPEN MORTGAGE LLC',
#  'CITIZENS BANK NA',
#  'CASTLE MORTGAGE CORPORATION DBA',
#  'HOMEBRIDGE FINANCIAL SERVICES INC DBA',
#  'OAKWOOD BANK',
#  'VISTA BANK',
#  'UBANK',
#  'ENTRUST FINANCIAL CORPORATION',
#  '7 BRIDGE FUNDING LLC',
#  'TRINITY OAKS MORTGAGE LLC',
#  'SOUTHERN HILLS PROPERTY GROUP LLC',
#  'INTERLINC MORTGAGE SERVICES LLC',
#  'BMO HARRIS BANK NA',
#  'MIMUTUAL MORTGAGE',
#  'BLACK LABEL CAPITAL LLC',
#  'DRAPER&KRAMER MORTGAGE CORP',
#  'BLUESTONE FINANCE LLC',
#  'FIRST FUNDING REALTY I LLC',
#  'RAYMOND JAMES BANK',
#  'DAS ACQUISITION COMPANY LLC',
#  'FORT WORTH COMMUNITY CREDIT UNION',
#  'SUCCESS MORTGAGE PARTNERS INC DBA',
#  'BXM FUNDING LLC',
#  'BANCORPSOUTH BANK',
#  'NATIONS LENDING CORPORATION',
#  'BANK OF THE WEST AGENT',
#  'FIRST CITIZENS BANK&TRUST COMPANY',
#  'COLONIAL NATIONAL MORTGAGE',
#  'BELL ROCK INCOME FUND 1 LLC',
#  'STIFEL BANK&TRUST',
#  'FIRST NATIONAL BANK OF AMERICA',
#  'BANK7',
#  'IMAP ACQ LLC',
#  'DFW INVESTOR LENDING LLC',
#  'DALLAS CAPITAL BANK NA',
#  'LUMINATE HOME LOANS INC',
#  'SOUTHWESTERN NATIONAL BANK',
#  'COMMERCIAL BANK OF TEXAS NA',
#  'FIRST RATE FINANCIAL LLC',
#  'FIRST STATE BANK',
#  'WELLS FARGO BANK',
#  'COLONIAL SAVINGS FA',
#  'TITUS38 LLC DBA',
#  'CMC HOME LENDING',
#  'LONGBRIDGE FINANCIAL LLC',
#  'QUEST TRUST COMPANY',
#  'THE MORTGAGE LINK INC',
#  '212 LOANS LLC',
#  'OPTIMUM FIRST INC',
#  'HANNAH FUNDING LLC',
#  'LAKESIDE BANK',
#  'ANCHOR LOANS LP',
#  'LOAN SIMPLE INC',
#  'FAIRWAY INDEPENDENT MORTGAGE CORPORATION DBA',
#  'DOMINION FINANCIAL SERVICES LLC',
#  'GENHOME MORTGAGE CORPORATION',
#  'LONE STAR CREDIT UNION',
#  'TRUSTED RATE INC',
#  'BROADWAY NATIONAL BANK',
#  'COMMISSIONER OF HOUSING&URBAN DEVELOPMENT',
#  'DEVON BANK',
#  'FC LENDING LTD',
#  'U S SMALL BUSINESS ADMINISTRATION',
#  'NP INC',
#  'KNOCK LENDING LLC',
#  'PIONEER OAKS CAPITAL FUNDING LLC DBA',
#  'TEXAS PRIDE LENDING LLC',
#  'GREATER TEXAS FEDERAL CREDIT UNION',
#  'ZEUSLENDING.COM',
#  'I&T BUILDERS CORPORATION',
#  'PRUNY LLC',
#  'WILDCAT LENDING FUND THREE LP',
#  'ONE WORLD BANK',
#  'VIP INDEPENDENT MORTGAGE INC',
#  'INTERCAP LENDING INC',
#  'S&W REAL ESTATE INVESTMENTS LLC',
#  'BTH BANK NATIONAL ASSOCIATION',
#  'ENTERPRISE BANK&TRUST',
#  'AMERICAN FINANCIAL NETWORK INC DBA',
#  'WASHINGTON FEDERAL BANK',
#  'LENDING BASE INC',
#  'MEGA CAPITAL FUNDING INC',
#  'METRO CITY BANK',
#  'MAPLEMARK BANK',
#  'AMPLIFY CREDIT UNION',
#  'LIBERTY CAPITAL BANK',
#  'UNITED TEXAS BANK',
#  'RLM MORTGAGE DBA',
#  'LHM FINANCIAL CORPORATION',
#  'SUBLIME FINANCIAL LLC',
#  'R BANK',
#  'DMD FINANCIAL CORPORATION DBA',
#  'TEXAS TECH FEDERAL CREDIT UNION',
#  'GOLD STAR MORTGAGE FINANCIAL GROUP CORPORATION',
#  'NORTHPOINTE BANK',
#  'EVOLVE BANK&TRUST',
#  'ALLY BANK CORP',
#  'AGN LLC',
#  'HOME LOAN EXPERT LLC',
#  'FLASH RAISE FUNDING LLC',
#  'SOUTHEAST TEXAS HOUSING FINANCE CORPORATION',
#  'STATE BANK OF TEXAS',
#  'KIND LENDING LLC DBA',
#  'CONFIA CAPITAL INC',
#  'IFP FUND I LLC',
#  'SOUTHSIDE BANK',
#  'KEYBANK NATIONAL ASSOCIATION',
#  'SECRETARY OF THE US DEPARTMENT OF HOUSING&URBAN DEVELOPMEN',
#  'DEEPHAVEN MORTGAGE LLC',
#  'EFINITY FINANCIAL INC DBA',
#  'CBRE CAPITAL MARKETS INC',
#  'INGRAM BLAKE ENTERPRISES INC',
#  'PHILIPS J MORTGAGE INC',
#  'S31 TAX FUNDING LLC',
#  'CFS PRILAND LLC',
#  'INDEPENDENT OAKS CAPITAL FUNDING LLC DBA',
#  'BANK OF WHITTIER NA',
#  'UNITED FAITH MORTGAGE',
#  'TBK BANK SSB',
#  'AMERIDREAM MORTGAGE GROUP LLC',
#  'AMERICAN MORTGAGE ADVISERS INC',
#  'FIRST REPUBLIC BANK',
#  'ALL CREDIT CONSIDERED MORTGAGE INC',
#  'HARMONY BANK',
#  'BARRETT FINANCIAL GROUP LLC',
#  'LAS COLINAS FEDERAL CREDIT UNION',
#  'GENERAL MORTGAGE CAPITAL CORPORATION',
#  'FIRST NATIONAL BANK OF WINNSBORO',
#  'BARCO CAPITAL LP',
#  'BROWER GROUP LLC',
#  'ORCHARD MORTGAGE LLC',
#  'COMMONWEALTH ANNUITY&LIFE INSURANCE COMPANY',
#  'LOANPEOPLE LLC',
#  'GSB MORTGAGE INC',
#  'ARCHWEST FUNDING LLC',
#  'RELIANT COMPANIES INC DBA',
#  'PETRA HOME LENDING',
#  'FIRST OPTION MORTGAGE LLC',
#  'ELITE FINANCING GROUP LLC',
#  'ALL WESTERN MORTGAGE INC',
#  'E MORTGAGE CAPITAL INC',
#  'CONSTANT INVESTMENTS INC DBA',
#  'ACHIEVA MORTGAGE FUNDING LLC',
#  'LUONG PHILLIP',
#  'LEADERONE FINANCIAL CORPORATION',
#  'KINDRED HOMELOANS LLC',
#  'COUCH PROPERTIES LLP',
#  'SOUTHWEST FINANCIAL FEDERAL CREDIT UNION',
#  'AMERICAN FINANCE HOUSE LARIBA',
#  'EAST CAPITAL FUNDING LLC',
#  'NORTH AMERICAN SAVINGS BANK FSB',
#  'NARAYAN LAXMI ENTERPRISES INC DBA',
#  'JPMORGAN CHASE BANK',
#  'ADVISORS MORTGAGE GROUP LLC',
#  'KELLER MORTGAGE LLC DBA',
#  'HANCOCK WHITNEY BANK',
#  'HD LENDERS LLC',
#  'PALISADE INVESTMENTS LLC',
#  'VERABANK NATIONAL ASSOCIATION',
#  'HOUSEMAX FUNDING LLC',
#  'FIRST GUARANTY BANK',
#  'CELEBRITY HOME LOANS LLC',
#  'AMERICAN BANK OF COMMERCE',
#  'FLAGSTAR BANK FSB',
#  'AXEN MORTGAGE',
#  'METRO MEDICAL CREDIT UNION',
#  'DALLAS AREA HABITAT FOR HUMANITY INC',
#  'GREEN BRICK MORTGAGE LLC',
#  'BNC NATIONAL BANK',
#  'HOMEWOOD MORTGAGE LLC',
#  'GREENBOX LOANS INC',
#  'SPECTRA BANK',
#  'RBC BANK GEORGIA NA',
#  'HUNTINGTON NATIONAL BANK',
#  'STOA 3 LLC',
#  'DOMINION BANK',
#  'GRAHAM MORTGAGE CORPORATION',
#  'PFN LENDING GROUP INC',
#  'RED DIAMOND HOME LOANS LLC',
#  'BNY MELLON NA',
#  'TOGETHER CREDIT UNION',
#  'AFFIRM HOME LOANS LLC',
#  'TRELLY FINANCE LLC',
#  'RESICENTRAL LLC',
#  'REPUBLIC STATE MORTGAGE CO',
#  'GRAND BANK',
#  'MEMBER FIRST MORTGAGE LLC',
#  'TVC FUNDING II LLC',
#  'INTOUCH CREDIT UNION',
#  'EQUITY TRUST COMPANY',
#  'CENDERA BANK NA',
#  'AMERICAN STATE BANK',
#  'MIDWEST MORTGAGE ASSOCIATES CORP',
#  'STRATA TRUST COMPANY',
#  'URBAN COYOTE HOLDINGS LLC',
#  'FDRE INC',
#  'GOAT FUNDING LLC',
#  'AXOS BANK',
#  'CAROLCORP INC',
#  'AMERICAN FINANCING CORPORATION',
#  'COP ENTERPRISES LLC',
#  'ALLY BANK',
#  'KHOURY ELIAS DBA',
#  'TOMO MORTGAGE LLC',
#  'ARC HOME LOANS LLC',
#  'JLL REAL ESTATE CAPITAL LLC',
#  'ABSOLUTE MORTGAGE&LENDING',
#  'PAJ ENTERPRISES LLC DBA',
#  'M SQUARED FINANCIAL LLC',
#  'AMERIHOME MORTGAGE COMPANY LLC',
#  'JT INC DBA',
#  'PAVILLION BANK',
#  'WINTRUST MORTGAGE',
#  'DEEP ELLUM FUNDING LLC DBA',
#  'TEXAS DOW EMPLOYEES CREDIT UNION',
#  'CENTRAL MORTGAGE FUNDING LLC',
#  'FIRST NATIONAL BANK TEXAS',
#  'FIRST NATIONAL BANK&TRUST COMPANY OF WEATHERFORD DBA',
#  'WORTHINGTON BANK',
#  'GREYSTONE SERVICING COMPANY LLC',
#  'AMERICAN FIRST NATIONAL BANK',
#  'AMERIFIRST FINANCIAL INC',
#  'INVESTOR MORTGAGE FINANCE LLC',
#  'DVKT LLC',
#  'COMMUNITY NATIONAL BANK&TRUST OF TEXAS',
#  'BRODERICK STREET M HOLDINGS LLC',
#  'CAPITAL CONCEPTS INC',
#  'TEXAS CREDIT UNION',
#  'CATALYST RESOURCE GROUP INC DBA',
#  'AER REAL ESTATE HOLDINGS LLC',
#  'LEND SMART MORTGAGE LLC',
#  'WILMINGTON TRUST NATIONAL ASSOCIATION TR',
#  'READYCAP LENDING LLC',
#  'MESQUITE CREDIT UNION',
#  'N 2 DEEP INC',
#  'FIRST EQUITY MORTGAGE INCORPORATED DBA',
#  'NETWORK CAPITAL FUNDING CORPORATION',
#  'WENTWORTH CAPITAL LLC',
#  'LUONG JOE',
#  'DAVENPORT INVESTMENT GROUP LLC',
#  'LOBO ROJO LLC',
#  'LENDING PRAXES LLC',
#  'HCP MORTGAGE LLC',
#  'SABAL CAPITAL II LLC',
#  'WALKER&DUNLOP LLC',
#  'CHAMPIONS FUNDING LLC',
#  'COMMUNITY NATIONAL BANK',
#  'FEDERAL SAVINGS BANK',
#  'BAXTER CREDIT UNION',
#  'CARRANZA INVESTMENTS LLC',
#  'CR LENDING LLC',
#  'TAX LOANS USA LTD',
#  'TRUIST BANK AGENT',
#  'EMPORIUM TPO LLC',
#  'NATIONWIDE MORTGAGE BANKERS INC',
#  'BARCO FUNDING LP',
#  'FIRST SAVINGS BANK',
#  'VETERANS LAND BOARD OF THE STATE OF TEXAS',
#  'WOLBE ELLIS',
#  'HURST REAL ESTATE INC',
#  'AXIA FINANCIAL LLC',
#  'GOODLIFE HOME LOANS',
#  'HARD MONEY FAST LLC',
#  'RAIN CITY CAPITAL LLC',
#  'INSTAMORTGAGE INC',
#  'TC RIVERVIEW PARTNERSHIP',
#  'BAY MOUNTAIN FUND I LLC',
#  'VONTIVE INC',
#  'GRAND HOME LOANS LLC',
#  'AMERICAN BANK NA',
#  'DIVERSIFIED REAL ESTATE HOLDINGS LLC',
#  'STRONG HOME MORTGAGE LLC',
#  'WHITE ROCK FINANCE LLC',
#  'HUNT G L COMPANY INC',
#  'METRO CASA HOLDINGS LLC',
#  'NOBLE MORTGAGE&INVESTMENTS LLC',
#  'RIVERWOOD ENTERPRISES LP',
#  'BANFF CAPITAL LLC',
#  'MERCHANTS FUNDING LLC',
#  'NORTHERN TRUST COMPANY',
#  'SOUTH RIVER MORTGAGE LLC',
#  'LAKEVIEW COMMUNITY CAPITAL LLC',
#  'FIRSTBANK SOUTHWEST',
#  'SECURITY NATIONAL BANK OF OMAHA',
#  'IRON BRIDGE MORTGAGE FUND LLC',
#  'PCB BANK',
#  'AVOUE MARCHAND INVESTMENTS INC',
#  'SWIFT HOME LOANS INC',
#  'TOWNE MORTGAGE COMPANY',
#  'C&R METROPLEX HOUSES LLC',
#  'BANK OF HOPE',
#  'CITY LENDING INC',
#  'OAKTREE FUNDING CORP',
#  'UNION SQUARE CREDIT UNION',
#  'HOUSE FLIPPERS HARD MONEY 1 LLC',
#  'SAMPSON 852 LLC',
#  'NEIGHBORHOOD HOUSING SERVICES OF WACO INC',
#  'VISIO FINANCIAL SERVICES INC',
#  'SENTE MORTGAGE INC',
#  'MAZZMANIA LP',
#  'AMNET ESOP CORPORATION DBA',
#  'TEXAS REPUBLIC BANK',
#  'G CAPITAL LLC',
#  'BARTON CREEK LENDING GROUP LLC',
#  'JML CAPITAL MANAGEMENT INC',
#  'READYCAP COMMERCIAL LLC',
#  'LENOVITZ MARSHALL',
#  'GUIDANCE RESIDENTIAL LLC',
#  'BERKADIA COMMERCIAL MORTGAGE LLC',
#  'CENTRAL TRUST BANK',
#  'GOLDEN BANK NATIONAL ASSOCIATION',
#  'PROSPERITY BANK FKA',
#  'VANTAGE BANK TEXAS',
#  'HPA CL2 MANAGING BORROWER LLC',
#  'FEDERAL HOME LOAN BANK OF DALLAS',
#  'DATCU',
#  'CEFCU',
#  'NORTHMARQ CAPITAL LLC',
#  'FIRST NATIONAL BANK OF MCGREGOR',
#  'PILGRIM BANK',
#  'GROVES CAPITAL INC',
#  'WILMINGTON TRUST NATIONAL ASSOCIATION',
#  'HOUSTON HOME LOAN INC',
#  'VANDERBILT MORTGAGE&FINANCE INC DBA',
#  'EMERALD DOLPHIN ENTERPRISES INC',
#  'PROVIDENCE BANK OF TEXAS SSB',
#  'CENTER STREET LENDING VIII SPE LLC',
#  'HIGHLAND HOMELOANS LLC',
#  'KWIK MORTGAGE CORPORATION',
#  'WALLIS BANK',
#  'SOFI BANK NATIONAL ASSOCIATION',
#  'CAPITAL ONE NATIONAL ASSOCIATION',
#  'CADENCE BANK FKA',
#  'SILICON VALLEY BANK',
#  'PHILIPOSE VARUGHESE',
#  'FIRST MID BANK&TRUST NA',
#  'FLORIDA CAPITAL BANK NA',
#  'AMERICAN NATIONAL INVESTORS CORP',
#  'BLESSING BRIAN',
#  'ANGEL OAK HOME LOANS LLC',
#  'PINNACLE FUNDING GROUP INC',
#  'GARLAND CITY',
#  'PILGRIM MORTGAGE LLC',
#  'SCHERTZ BANK&TRUST',
#  'STANDARD INSURANCE COMPANY',
#  'SECRETARY OF HOUSING & URBAN DEVELOPMENT',
#  'EXPRESS CAPITAL LENDING LLC',
#  'VELLUM MORTGAGE INC',
#  'FIRST NATIONAL BANK TEXAS DBA',
#  'ARVEST BANK',
#  'VANDYK MORTGAGE CORPORATION',
#  'PAUL ROWNTREE 401 K PROFIT SHARING TRUST',
#  'BEDROCK MORTGAGE FUND LLC',
#  'TMS VENTURES LLC',
#  'STALLION TEXAS REAL ESTATE FUND LLC',
#  'DFW METRO PROPERTIES LLC',
#  'UNKNOWN',
#  'RFLF 5 LLC',
#  'FIFTH THIRD BANK NATIONAL ASSOCIATION',
#  'NEWTEK SMALL BUSINESS FINANCE LLC',
#  'PROPERTY TAX LENDING LP',
#  'SOUTHTRUST BANK NA',
#  'SIERRA PACIFIC MORTGAGE COMPANY INC',
#  'SOUTHERN STAR CAPITAL LLC DBA',
#  'TEXAS CAPITAL BANK AGENT',
#  'REVERSE MORTGAGE FUNDING LLC',
#  'AMERANT MORTGAGE LLC',
#  'FASIHNIA FARHAD',
#  'SIRVA MORTGAGE INC',
#  'CABB FINANCE LLC',
#  'EASYSTREET CAPITAL INVESTMENTS LLC',
#  'AHL FUNDING DBA',
#  'PRINCETON MORTGAGE CORPORATION',
#  'INVESTOR LENDING LLC',
#  'RIVER CITY MORTGAGE LLC',
#  'FIRST CENTENNIAL MORTGAGE CORPORATION',
#  'E2 LENDING LLC',
#  'BELLWETHER ENTERPRISE REAL ESTATE CAPITAL LLC',
#  'TEXAS REGIONAL BANK',
#  'LEGEND LENDING CORPORATION',
#  'ENDEAVOR CAPITAL LLC',
#  'JET HOMELOANS LLC',
#  'COREVEST AMERICAN FINANCE LENDER LLC',
#  'QUANTA FINANCE LLC',
#  'NORTH TEXAS HOMES LLC',
#  'PACIFIC WESTERN BANK',
#  'HOMETOWN EQUITY MORTGAGE LLC DBA',
#  'LOANUNITED.COM LLC',
#  'NORTH TEXAS CERTIFIED DEVELOPMENT CORPORATION',
#  'GUARANTY FEDERAL MORTGAGE LLC',
#  'LAND HOME FINANCIAL SERVICES INC',
#  'COLLIERS MORTGAGE LLC',
#  'D REALTY INVESTMENTS INC',
#  'PREMIA MORTGAGE LLC DBA',
#  'LOGAN FINANCE CORPORATION',
#  'CBRE MULTIFAMILY CAPITAL INC',
#  'GLOBAL HOME FINANCE INC',
#  'RELIANCE FIRST CAPITAL LLC',
#  'SILVER HILL FUNDING LLC',
#  'CITIZENS 1ST BANK TYLER TEXAS',
#  'TREEHOUSE FINANCIAL LLC 401 K PROFIT SHARING TRUST',
#  'MDA ENTERPRISES INC',
#  'DATCU CREDIT UNION',
#  'NATIONS DIRECT MORTGAGE LLC',
#  'GREATER TEXAS CAPITAL CORPORATION',
#  'KADLOGIC INC',
#  'VALLIANCE BANK',
#  'MORELAND VENTURES LLC',
#  'STELLAR BANK',
#  'TAYLOR MORRISON HOME FUNDING INC',
#  'FIRST NATIONAL BANK OF CENTRAL TEXAS',
#  'CATHAY BANK',
#  'DEUTSCHE BANK AG NEW YORK BRANCH',
#  'HANMI BANK',
#  'TOYOTA FINANCIAL CONSUMER SOLUTIONS',
#  'bank',
#  'credit union',
#  'mortgage',
#  'wyndham vacation resorts inc',
#  'veterans affairs',
#  'board',
#  'city of panama city',
#  'secretary of housing and urban development',
#  'bluegreen vacations corporation',
#  'florida housing finance corporation',
#  'habitat for humanity of bay county florida inc',
#  'kiavi funding inc',
#  'grantee',
#  'rural housing service',
#  'third federal savings and loan association of cleveland',
#  'insurance',
#  'federal',
#  'navigator private capital llc',
#  'private capital',
#  'bay county',
#  'walker & dunlop llc',
#  'credit union',
#  'housing',
#  'wells fargo',
#  'us small business administration',
#  'lending',
#  'bbva usa',
#  'usa bbva',
#  'farm credit of northwest florida',
#  'aloha capital llc',
#  'secretary of veterans affairs',
#  'cadence bank',
#  'secretary of housing&urban development',
#  'united wholesale mortgage llc',
#  'bank of america na',
#  'rocket mortgage llc',
#  'credit union of texas',
#  'prosperity bank',
#  'everett financial inc dba',
#  'texas state affordable housing corporation',
#  'town square mortgage&investments llc dba',
#  'jpmorgan chase bank na',
#  'frost bank',
#  'mortgage electronic registration systems inc',
#  'fairway independent mortgage corporation',
#  'guaranteed rate inc',
#  'crosscountry mortgage llc',
#  'texas department of housing&community affairs',
#  'texasbank',
#  'rocket mortgage llc fka',
#  'dhi mortgage company ltd',
#  'wells fargo bank na',
#  'loandepot.com llc',
#  'first united bank&trust company',
#  'pnc bank national association',
#  'cadence bank',
#  'cardinal financial company limited partnership',
#  'first horizon bank',
#  'origin bank',
#  'comerica bank',
#  'federal housing commissioner',
#  'highlands residential mortgage ltd',
#  'nationstar mortgage llc dba',
#  'lennar mortgage llc',
#  'cmg mortgage inc dba',
#  'truist bank',
#  'sfmc lp dba',
#  'first financial bank na',
#  'ark la tex financial services llc dba',
#  'integrity mortgage corporation of texas',
#  'prosperity home mortgage llc',
#  'primelending',
#  'zions bancorporation na dba',
#  'guild mortgage company llc',
#  'mortgage research center llc dba',
#  'city credit union',
#  'bokf na dba',
#  'pennymac loan services llc',
#  'thrive mortgage llc',
#  'kiavi funding inc',
#  'navy federal credit union',
#  'cornerstone home lending',
#  'simmons bank',
#  'inwood national bank',
#  'willow bend mortgage company llc',
#  'veritex community bank',
#  'provident funding associates lp',
#  'american airlines federal credit union',
#  'texas trust credit union',
#  'trident realty investments llc',
#  'wildcat lending fund one lp',
#  'randolph brooks federal credit union',
#  'citibank na',
#  'city bank dba',
#  'southwest funding lp',
#  'texans credit union',
#  'first national bank',
#  'caliber home loans inc',
#  'midfirst bank',
#  'swbc mortgage corp',
#  'independent bank',
#  'first bank',
#  'u s bank national association',
#  'aspire financial inc dba',
#  'lower llc dba',
#  'pulte mortgage llc',
#  'discover bank',
#  'amcap mortgage ltd dba',
#  'neighborhood loans inc',
#  'gateway mortgage',
#  'secretary of veterans affairs',
#  'capital fund i llc isaoa',
#  'capital fund i llc',
#  'rflf 7 llc',
#  'american national bank of texas',
#  'mustang credit solutions llc',
#  'pentagon federal credit union',
#  'guardian mortgage',
#  'interbank',
#  'grantee',
#  'aml funding llc dba',
#  'north dallas bank&trust co',
#  'morgan stanley private bank national association',
#  'easy street capital investments llc',
#  'paramount residential mortgage group inc',
#  'synergy one lending inc',
#  'texas security bank',
#  'dallas city',
#  'securitynational mortgage company',
#  'plainscapital bank',
#  'academy mortgage corporation',
#  'texas bank&trust company',
#  'american financial network inc',
#  'newrez llc dba',
#  'velocio mortgage llc',
#  'first united bank&trust co',
#  'mortgage link inc',
#  'boomerang finance sub reit llc',
#  'gardner financial services ltd dba',
#  'civic financial services llc',
#  'eustis mortgage corp dba',
#  'goodleap llc',
#  'mattamy home funding llc',
#  'carrington mortgage services llc',
#  'regions bank',
#  'churchill mortgage corporation',
#  'texas republic bank na',
#  'susser bank',
#  'originpoint llc',
#  'uif corporation',
#  'bpl mortgage trust llc',
#  'brookhollow mortgage services ltd',
#  'texas brand bank',
#  'brazos national bank',
#  'freedom mortgage corporation',
#  'certified funding lp',
#  'amcap mortgage ltd',
#  'loan ranger capital investments reit llc',
#  'eecu',
#  'amerisave mortgage corporation',
#  'bank of desoto na',
#  'pnc bank na',
#  'equity prime mortgage llc',
#  'resource one credit union',
#  'nations reliable lending llc',
#  'double backflip llc',
#  'great western financial services inc',
#  'garland housing finance corporation garland texas',
#  'crosstimbers capital inc',
#  'bank of england',
#  'guaranteed rate affinity llc',
#  'home point financial corporation',
#  'umortgage llc',
#  'homebridge financial services inc',
#  'pegasus bank',
#  'next door lending',
#  'better mortgage corporation isaoa',
#  'bank ozk',
#  'vip mortgage inc',
#  'amwest funding corp',
#  'scf jake lp',
#  'bay equity llc',
#  'lima one capital llc',
#  'network funding lp',
#  'dallas neighborhood homes',
#  'bosse lending llc',
#  'international bank of commerce',
#  'lendingone llc',
#  'ubs bank usa',
#  'nuwave lending llc',
#  'broker solutions inc dba',
#  'tolleson private bank',
#  'wintex group llc dba',
#  'regions bank dba',
#  'rflf 4 llc',
#  'planet home lending llc',
#  'southwest airlines federal credit union',
#  'lbk lending llc',
#  'royal united mortgage llc',
#  'ntfn inc',
#  'panorama mortgage group llc dba',
#  'american national bank&trust',
#  'mci preferred income fund iv llc',
#  'rlm mortgage llc dba',
#  'newrez llc',
#  'nbkc bank',
#  'benchmark bank',
#  'first funding investments inc',
#  'ceasons holdings llc',
#  'movement mortgage llc',
#  'a&d mortgage llc',
#  'bank of the west',
#  'crossfirst bank',
#  'new american funding llc',
#  'plaza home mortgage inc',
#  'cornerstone home lending inc',
#  'ocmbc inc',
#  'mci mortgage inc',
#  'centennial bank dba',
#  'bank of america',
#  'click n close inc',
#  'b1bank',
#  'm i financial llc',
#  'homebank texas',
#  'lifestyle home lending llc',
#  'american pacific mortgage corporation',
#  'flagstar bank na',
#  'usaa federal savings bank',
#  'angel oak mortgage solutions llc',
#  'wells fargo bank national association',
#  'americas credit union',
#  'calcon mutual mortgage llc dba',
#  'rosa elvin john bankers insurance dba',
#  'encore bank',
#  'great plains national bank',
#  'east west bank',
#  'cherry creek mortgage llc',
#  'independent bank dba',
#  'nbh bank',
#  'citizens national bank of texas',
#  'change lending llc',
#  'ibnet co ltd',
#  'azben limited llc',
#  'citadel servicing corporation dba',
#  'mutual of omaha mortgage inc',
#  'geneva financial llc',
#  't2 financial llc dba',
#  'guaranty bank&trust na',
#  'nexbank',
#  'union home mortgage corp',
#  'firstcapital bank of texas na',
#  'rcn capital llc',
#  'zillow home loans llc',
#  'homexpress mortgage corp',
#  'dallas mortgage associates',
#  'liberty national bank',
#  'trez capital 2015 corporation',
#  'american neighborhood mortgage acceptance company llc',
#  'digital federal credit union',
#  'clm mortgage inc',
#  'sun west mortgage company inc',
#  'lakeview loan servicing llc',
#  'cattlemens bank',
#  ...]

# %%
import pandas as pd

#  Read the excel file
dfk = pd.read_csv('KeywordsRem_Dallas.csv') 

# Get the list of values
caps = dfk['Keywords'].tolist()

lowers = [x.lower() for x in caps]

elimkeys = caps + lowers

elimkeys



# df = pd.read_csv('Bay_county_FL_5.csv')

df = pd.read_csv('Dallas-8-22-to-8-23.csv')

df = df[df['Grantee'].str.contains('|'.join(elimkeys))==False]


# df
# from itables import show
# show(df , paging=True)

# r= df['Grantee'].value_counts()

# from itables import show
#         show(r)

# with pd.option_context('display.max_rows', None,
#                        'display.max_colwidth', 100,
                      
#                       ): 
#     display(r)

# r


# from itables import show

# show(r , paging=True)


# from itables import init_notebook_mode
# init_notebook_mode(all_interactive=True)


# df = pd.DataFrame(r)
# df


r= df['Grantee'].value_counts()
# print(r)
r

r.to_csv('output_test.csv')
