# %%
#https://www.google.com/search?q=pandas+if+the+name+matches+it+shoudl+delete+the+excel+row&oq=pandas+if+the+name+matches+it+shoudl+delete+the+excel+row&aqs=chrome.0.69i59.392j0j7&sourceid=chrome&ie=UTF-8

# %%
import pandas as pd

#  Read the excel file
dfk = pd.read_csv('KeywordsRem_Dallas.csv') 

# Get the list of values
caps = dfk['Keywords'].tolist()

lowers = [x.lower() for x in caps]

elimkeys = caps + lowers

elimkeys



# df = pd.read_csv('Bay_county_FL_5.csv')

df = pd.read_csv('Dallas-8-22-to-8-23.csv')

df = df[df['Grantee'].str.contains('|'.join(elimkeys))==False]


# from itables import show
# show(df , paging=True)

df
from itables import show
show(df , paging=True)

# r= df['Grantee'].value_counts()

# from itables import show
#         show(r)

# with pd.option_context('display.max_rows', None,
#                        'display.max_colwidth', 100,
                      
#                       ): 
#     display(r)

# r


# from itables import show

# show(r , paging=True)


# from itables import init_notebook_mode
# init_notebook_mode(all_interactive=True)


# df = pd.DataFrame(r)
# df


# r= df['Grantee'].value_counts()
# print(r)
# r

# r.to_csv('output_test.csv')
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="5a7ec48d-42ca-4fa0-aa92-30b5dff44526" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>on (i)</th>
#       <th>Unnamed: 1</th>
#       <th>Unnamed: 2</th>
#       <th>Grantor</th>
#       <th>Grantee</th>
#       <th>Doc Type</th>
#       <th>Recorded Date</th>
#       <th>Doc Number</th>
#       <th>Book/Volume/Page</th>
#       <th>Town</th>
#       <th>Legal Description</th>
#     </tr>
# ...
