# %%
#https://www.google.com/search?q=pandas+if+the+name+matches+it+shoudl+delete+the+excel+row&oq=pandas+if+the+name+matches+it+shoudl+delete+the+excel+row&aqs=chrome.0.69i59.392j0j7&sourceid=chrome&ie=UTF-8

# %%
import pandas as pd
# Read the excel file
dfk = pd.read_csv('KeywordsRem_Dallas.csv') 

# Get the list of values
caps = dfk['Keywords'].tolist()

lowers = [x.lower() for x in caps]

elimkeys = caps + lowers

# df = pd.read_csv('Bay_county_FL_5.csv')

df = pd.read_csv('Dallas-8-21-to-8-23.csv', low_memory=False)


df = df[df['Grantee'].str.contains('|'.join(elimkeys))==False]
# df

from itables import show
show(df , paging=True)



r= df['Grantee'].value_counts()

# r.to_csv('output1.csv', index=False)
r.to_csv('out_Dallas_2021-2023.csv')


# r= df['Grantee'].value_counts()

# from itables import show
#         show(r)

# with pd.option_context('display.max_rows', None,
#                        'display.max_colwidth', 100,
                      
#                       ): 
#     display(r)

# r


# from itables import show

# show(r , paging=True)


# from itables import init_notebook_mode
# init_notebook_mode(all_interactive=True)


# df = pd.DataFrame(r)
# df
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="562e93c6-8c02-4840-b768-d0ed58c6f491" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>on (i)</th>
#       <th>Unnamed: 1</th>
#       <th>Unnamed: 2</th>
#       <th>Grantor</th>
#       <th>Grantee</th>
#       <th>Doc Type</th>
#       <th>Recorded Date</th>
#       <th>Doc Number</th>
#       <th>Book/Volume/Page</th>
#       <th>Town</th>
#       <th>Legal Description</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[0, "on (i)", "https://dallas.tx.publicsearch.us/img/icon_ellipsis.a3c830b130a1717097fbd51371f6a54d.svg", NaN, "NOYOLA DAVID FIGUEROA", "1.0 CFSFH LLC", "DEED OF TRUST", "8/2/21", "2.02E+11", "--/--/--", "BALCH SPRINGS", "Subdivision- Name: FIFTH INSTALLMENT OF SPRING OAKS Lot: 18 Block: 4 CITY: BALCH SPRINGS,, Reference - 533 / 1940"], [2, "on (i)", "https://dallas.tx.publicsearch.us/img/icon_ellipsis.a3c830b130a1717097fbd51371f6a54d.svg", NaN, "CE&A INVESTORS LLC", "ABIDE INC", "DEED OF TRUST", "8/2/21", "2.02E+11", "--/--/--", "DALLAS", "Subdivision- Name: BROWNWOOD PARK Lot: 7 Block: D CITY: DALLAS,, Reference - 18 / 55"], [15, "on (i)", "https://dallas.tx.publicsearch.us/img/icon_ellipsis.a3c830b130a1717097fbd51371f6a54d.svg", NaN, "WHITMILL ROBERT", "AMERICAN ADVISORS GROUP", "DEED OF TRUST", "8/2/21", "2.02E+11", "--/--/--", "DALLAS", "Subdivision- Name: HIGHLAND HILLS NO 13 Lot: 38 Block: 8 CBLK: 8294, CITY: DALLAS,, Reference - 69201 / 1721"], [16, "on (i)", "https://dallas.tx.publicsearch.us/img/icon_ellipsis.a3c830b130a1717097fbd51371f6a54d.svg", NaN, "MARSHALL VERDEL", "AMERICAN ADVISORS GROUP", "DEED OF TRUST", "8/2/21", "2.02E+11", "--/--/--", "DALLAS", "Subdivision- Name: BRUTON TERRACE NO 7 Lot: 16 Block: B CBLK: 6735, CITY: DALLAS,, Reference - 39 / 221"], [17, "on (i)", "https://dallas.tx.publicsearch.us/img/icon_ellipsis.a3c830b130a1717097fbd51371f6a54d.svg", NaN, "FLOY