# %%
# https://pypi.org/project/fillpdf/
# https://www.youtube.com/watch?v=oM9XGmpbGyg&t=398s

import fillpdf
from fillpdf import fillpdfs

# %%
# get_form_fields(input_pdf_path, sort=False, page_number=None)


# write_fillable_pdf(input_pdf_path, output_pdf_path, data_dict, flatten=False)

fillpdfs.print_form_fields('texas-con.pdf')
# Out:
# {'1 PARTIES The parties to this contract are': '',
# 'Seller and': '',
# 'A LAND Lot': '',
# 'Block': '',
# 'undefined': '',
# 'Addition City of': '',
# 'County of': '',
# 'Texas known as': '',
# 'be removed prior to delivery of possession': '',
# 'undefined_2': '',
# 'B Sum of all financing described in the attached': '',
# 'undefined_3': '',
# 'Check Box2': '',
# 'Loan Assumption Addendum': '',
# 'undefined_4': '',
# 'undefined_5': '',
# 'i will not be amended or deleted from the title policy or': '',
# 'ii will be amended to read shortages in area at the expense of': '',
# 'A TITLE POLICY Seller shall furnish to Buyer at': '',
# 'Sellers': '',
# 'Seller': '',
# 'to escrow agent within 1': '',
# 'Initialed for identification by Buyer': '',
# 'undefined_8': '',
# 'and Seller': '',
# 'undefined_9': '',
# 'Page 2 of 10': '',
# 'undefined_6': '',
# 'other party in writing before entering into a contract of sale  Disclose if applicable': '',
# 'undefined_7': '',
# ...

# %%
fillpdfs.get_form_fields('texas-con.pdf')
#form = fillpdfs.fillpdf.load('texas-con.pdf')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 fillpdfs.get_form_fields('texas-con.pdf')
# ----> 2 form = fillpdfs.fillpdf.load('texas-con.pdf')
#
# AttributeError: module 'fillpdf.fillpdfs' has no attribute 'fillpdf'

# %%
data_dict = {'1 PARTIES The parties to this contract are': 'the parties',
'Seller and': 'the seller and',
'A LAND Lot': 'A LAND Lot',
'Block': 'Block',
'undefined': 'undefined',
'Addition City of': 'Addition City',
'County of': '',
'Texas known as': '',
'be removed prior to delivery of possession': '',
'undefined_2': '',
'B Sum of all financing described in the attached': '',
'undefined_3': '',
'Check Box2': '',
'Loan Assumption Addendum': '',
'undefined_4': '',
'undefined_5': '',
'i will not be amended or deleted from the title policy or': '',
'ii will be amended to read shortages in area at the expense of': '',
'A TITLE POLICY Seller shall furnish to Buyer at': '',
'Sellers': '',
'Seller': '',
'to escrow agent within 1': '',
'Initialed for identification by Buyer': '',
'undefined_8': '',
'and Seller': '',
'undefined_9': '',
'Page 2 of 10': '',
'undefined_6': '',
'other party in writing before entering into a contract of sale  Disclose if applicable': '',
'undefined_7': '',
'as earnest money to': '',
'address Buyer shall deliver': '',
'earnest money of': '',
'to escrow agent within': '',
'the Title Company and Buyers lenders Check one box only': '',
'Sellers_2': '',
