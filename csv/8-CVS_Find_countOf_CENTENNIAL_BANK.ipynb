# %%
# https://stackoverflow.com/questions/1801668/convert-a-list-with-strings-all-to-lowercase-or-uppercase

import pandas as pd
import numpy as np

# %%
# Fnd the count for CENTENNIAL BANK


# Read the CSV file
df = pd.read_csv('Bay_county_FL_c1.csv')

# Find the count of the specific name
cbCount = df['Grantee'].value_counts()['CENTENNIAL BANK']

# Print the count
print("cbCount =", cbCount)  # Result = 133  But it has 573


wfbcount = df['Grantee'].value_counts()['WELLS FARGO BANK']

# Print the count
print("wfb =", wfbcount)  # Result = 300  But it has 402


wfcount = df['Grantee'].value_counts()['WELLS FARGO']

# Print the count
print("wf =", wfcount)




DocLinkscount = df['DocLinks'].value_counts()[1]
print("DocLinkscount =", DocLinkscount)




count_row = df.shape[0]  # Gives number of rows
count_col = df.shape[1]  # Gives number of columns

print("count_row =", wfcount)
print("count_col =", wfcount)
df
# Out:
# cbCount = 133
# wfb = 300
# wf = 2
# DocLinkscount = 23855
# count_row = 2
# count_col = 2
#       Status                                           Grantor  \
# 0          V                     BOOTH BARBARA A\nBOOTH PAUL S
# 1          V                               PHL INVESTMENTS LLC
# 2          V  PEREZ LUIS ALBERTO CUBAS\nPRADO DANIELA CARDENAS
# 3          V                  CLARK JAMES A JR\nCLARK KELSIE M
# 4          V                                KRASINSKAS KRISTEN
# ...      ...                                               ...
# 25143      V                  ARCHIE ANGELA\nGRIESE DAYJUANA L
# 25144      V                                       TOWNBRO LLC
# 25145      V                TEMPLES CHARLES A\nTEMPLES LAURA C
# 25146      V                                    PULLEM ROBERT
# 25147      V                                      KELLEY JENNY
#
#                                                  Grantee Record Date  \
# ...

# %%
# Fimd all the similar names like Bank of ameirca ,  Bank of ameirca of Texas. 


# Create a dataframe with some words
df = pd.DataFrame({'words': ['apple', 'banana', 'cherry']})

# Find all words that contain the string 'a'
df['words'] = df['words'].str.contains('a')

# Print the results
print(df)





# from itables import show

# show(df , paging=True)


# df = pd.read_csv('Bay_county_FL_5.csv')
# df = pd.read_csv('Bay_county_FL.csv')

# dff= pd.DataFrame(df)
# # print(df)


# df2 = df.pivot_table(index = ['Grantee'], aggfunc ='size')
# print(df2)


# Find the count of the specific name
# count = df['Grantee'].value_counts()['CENTENNIAL BANK']

# Print the count
# print(count)
# Out:
#    words
# 0   True
# 1   True
# 2  False

# %%
# https://www.geeksforgeeks.org/python-pandas-series-str-find/


import pandas as pd



df = pd.DataFrame({'name': ['Bank of America', 'Bank of America Atlanta', 'Bank of America Mortgage', 'John Doe', 'Jane Doe', 'Peter Smith']})

# Show the data where the name contains the substring "Doe"
df[df['name'].str.contains('Bank of America')]
# Out:
#                        name
# 0           Bank of America
# 1   Bank of America Atlanta
# 2  Bank of America Mortgage

# %%
# reading csv file from url
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")

# dropping null value columns to avoid errors
data.dropna(inplace = True)

# substring to be searched
sub ='Avery'

# creating and passing series to new column
data["Indexes"]= data["Name"].str.contains(sub)

# display
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary  Indexes
# 0            Texas  7730337.0     True
# ...
