# %%
import pandas as pd
dfk = pd.read_csv('KeywordsRem.csv') 

# Get the list of values
caps = dfk['Keywords'].tolist()



lowers = [x.lower() for x in caps]
# values
# s
all = caps + lowers
all
# Out:
# ['BANK',
#  'Credit Union',
#  'MORTGAGE',
#  'WYNDHAM VACATION RESORTS INC',
#  'VETERANS AFFAIRS',
#  'BOARD',
#  'CITY OF PANAMA CITY',
#  'SECRETARY OF HOUSING AND URBAN DEVELOPMENT',
#  'BLUEGREEN VACATIONS CORPORATION',
#  'FLORIDA HOUSING FINANCE CORPORATION',
#  'HABITAT FOR HUMANITY OF BAY COUNTY FLORIDA INC',
#  'KIAVI FUNDING INC',
#  'Grantee',
#  'RURAL HOUSING SERVICE',
#  'THIRD FEDERAL SAVINGS AND LOAN ASSOCIATION OF CLEVELAND',
#  'INSURANCE',
#  'FEDERAL',
#  'navigator private capital llc',
#  'private capital',
#  'BAY COUNTY',
#  'WALKER & DUNLOP LLC',
#  'CREDIT UNION',
#  'HOUSING',
#  'WELLS FARGO',
#  'US SMALL BUSINESS ADMINISTRATION',
#  'LENDING',
#  'BBVA USA',
#  'USA BBVA',
#  'FARM CREDIT OF NORTHWEST FLORIDA',
#  'ALOHA CAPITAL LLC',
#  'bank',
#  'credit union',
#  'mortgage',
#  'wyndham vacation resorts inc',
#  'veterans affairs',
#  'board',
#  'city of panama city',
#  'secretary of housing and urban development',
#  'bluegreen vacations corporation',
#  'florida housing finance corporation',
#  'habitat for humanity of bay county florida inc',
#  'kiavi funding inc',
#  'grantee',
#  'rural housing service',
#  'third federal savings and loan association of cleveland',
#  'insurance',
#  'federal',
#  'navigator private capital llc',
#  'private capital',
#  'bay county',
#  'walker & dunlop llc',
#  'credit union',
#  'housing',
#  'wells fargo',
#  'us small business administration',
#  'lending',
#  'bbva usa',
#  'usa bbva',
#  'farm credit of northwest florida',
#  'aloha capital llc']

# %%
# pd.read_csv('Bay_county_FL.csv')

# %%
# ar = ['BANK', 'VETERANS']

# df = df[df['Grantee'].str.contains('|'.join(ar))==False]
# df

ar = ['BANK', 'VETERANS']

df = df[df['Grantee'].str.lower().contains('|'.join(ar))==False]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 8
#       1 # ar = ['BANK', 'VETERANS']
#       2
#       3 # df = df[df['Grantee'].str.contains('|'.join(ar))==False]
#       4 # df
#       6 ar = ['BANK', 'VETERANS']
# ----> 8 df = df[df['Grantee'].str.lower().contains('|'.join(ar))==False]
#       9 df
#
# NameError: name 'df' is not defined

# %%
#pd.options.display.max_rows = 9999

df = pd.read_csv('Bay_county_FL.csv')

from itables import show

show(df)
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="b6fdef88-9d44-41a3-b2a1-a64688a9f8f3" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#
#       <th>Status</th>
#       <th>Grantor</th>
#       <th>Grantee</th>
#       <th>Record Date</th>
#       <th>Doc Type</th>
#       <th>Book Type</th>
#       <th>Book</th>
#       <th>Page</th>
#       <th>Clerk File #</th>
#       <th>Legal</th>
#       <th>DocLinks</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [
BLK 16 VENTURE OUT AT PANAMA CITY BEACH INC\\n", "NaN"], ["V", "ROBERTSON VIRGIL T", "BANKPLUS", "05/23/2023", "MORTGAGE", "OR", 4691.0, 603.0, 2023031599.0, "UNIT 2313 SHORES OF PANAMA I\\n", "NaN"], ["V", "MCPHILLIPS CONNOR D", "MERS\\nMORTGAGE ELECTRONIC REGISTRATION SYSTEMS INC", "05/23/2023", "MORTGAGE", "OR", 4691.0, 623.0, 2023031601.0, "L10 BAYWINDS\\n", "NaN"], ["V", "STROUD KAREN\\nWILLIAMS STACIE STROUD", "MORTGAGE ELECTRONIC REGISTRATION SYSTEMS INC\\nUNITED WHOLESALE MORTGAGE LLC", "05/23/2023", "MORTGAGE", "OR", 4691.0, 649.0, 2023031607.0, "L16 BLK 1 LAGUNA BEACH AMENDED\\n", "NaN"], ["V", "BARTLETT APRYL M\\nBARTLETT DANIEL P", "PANHANDLE CREDIT UNION", "05/23/2023", "MORTGAGE", "OR", 4691.0, 726.0, 2023031627.0, "L15 SUGAR SAND\\n", "NaN"], ["V", "BRYANT JASON\\nBRYANT WHITLEY", "FIRST BANK", "05/23/2023", "MORTGAGE", "OR", 4691.0, 742.0, 2023031631.0, "L5 BLK C KEY DEVELOPMENT ESTATES\\n", "NaN"], ["V", "BRINKERHOFF BETTY CHARLENE", "TRUSTMARK NATIONAL BANK", "05/23/2023", "MORTGAGE", "OR", 4691.0, 779.0, 2023031647.0, "L 18 & 19 BLK A DOTY SUBDIVISION\\n", "NaN"], ["V", "WINCKLER KAISA JO\\nWINCKLER ZACHARY", "MORTGAGE ELECTRONIC REGISTRATION SYSTEMS INC\\nROCKET MORTGAGE LLC", "05/23/2023", "MORTGAGE", "OR", 4691.0, 805.0, 2023031650.0, "PT PCL SEC 20-2S-13W\\n", "NaN"], ["V", "PRESS PRINT HOLDINGS LLC", "COMMUNITY BANK OF MISSISSIPPI", "05/23/2023", "MORTGAGE", "OR", 4691.0, 843.0, 2023031660.0, "PCL SEC 27-3-16\\n", "NaN"], ["V", "NGUYEN VAN THUY\\nPHUNG BRYANT", "MORTGAGE ELECTRONIC REGISTRATION SYSTEMS INC\\nROCKET MORTGAGE LLC", "05/23/2023", "MORTGAGE", "OR", 4691.0, 882.0, 2023031 ...

# %%
#pd.options.display.max_rows = 9999

df = pd.read_csv('Bay_county_FL.csv')

ar = ['BANK', 'VETERANS']

df = df[df['Grantee'].str.contains('|'.join(ar))==False]
# df

from itables import show

show(df , paging=True)
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="4b58d2bf-d0cf-479d-ba1d-fd7cc3428e40" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Status</th>
#       <th>Grantor</th>
#       <th>Grantee</th>
#       <th>Record Date</th>
#       <th>Doc Type</th>
#       <th>Book Type</th>
#       <th>Book</th>
#       <th>Page</th>
#       <th>Clerk File #</th>
#       <th>Legal</th>
#       <th>DocLinks</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data =
ELECTRONIC REGISTRATION SYSTEMS INC\\nROCKET MORTGAGE LLC", "05/23/2023", "MORTGAGE", "OR", 4691.0, 882.0, 2023031671.0, "PT PCL L 18 BLK B VENETIAN VILLA SECOND ADD\\n", "NaN"], [22, "V", "HUGHES JAMES ROBERT\\nSOUTHERN LIVE OAK INVESTMENT LLC", "WALLACE DENNIS\\nWALLACE KAY", "05/23/2023", "MORTGAGE", "OR", 4691.0, 915.0, 2023031680.0, "MISC PCLS N KEITHS BAY HARBOR ADD\\n", "NaN"], [23, "V", "SUCHY LISA MARIE\\nSUCHY MICHAEL CHRISTOPHER", "FBC MORTGAGE LLC\\nMORTGAGE ELECTRONIC REGISTRATION SYSTEMS INC", "05/23/2023", "MORTGAGE", "OR", 4691.0, 927.0, 2023031686.0, "L5 CEDAR CREEK PHASE 1\\n", "NaN"], [26, "V", "REDD MARILYN R\\nREDD MITCHELL H\\nREDD MITCHELL HOWARD", "MERS\\nTYNDALL FEDERAL CREDIT UNION", "05/23/2023", "MORTGAGE", "OR", 4691.0, 1102.0, 2023031741.0, "L10 BLK C FOREST PARK EAST\\n", "NaN"], [28, "V", "WEST KENNETH M", "MORTGAGE ELECTRONIC REGISTRATION SYSTEMS INC\\nSUN WEST MORTGAGE COMPANY INC", "05/23/2023", "MORTGAGE", "OR", 4691.0, 1145.0, 2023031748.0, "PT L103 & 104 PALM COVE PHASE TWO\\n", "NaN"], [29, "V", "DOUGLAS JOHN P", "SECRETARY OF HOUSING AND URBAN DEVELOPMENT", "05/23/2023", "MORTGAGE", "OR", 4691.0, 1162.0, 2023031749.0, "PCL SEC 4-1N-12\\n", "NaN"], [32, "V", "DEGARMO BRYAN\\nDEGARMO CAROLYN S", "MORTGAGE ELECTRONIC REGISTRATION SYSTEMS INC\\nROCKET MORTGAGE LLC", "05/23/2023", "MORTGAGE", "OR", 4691.0, 1254.0, 2023031764.0, "PART L17 BLK 1 EL CENTRO BEACH\\n", "NaN"], [33, "V", "MCILWEE CASSIE\\nMCILWEE SEAN B", "MORTGAGE ELECTRONIC REGISTRATION SYSTEMS INC\\nROCKET MORTGAGE LLC", "05/23/2023", "MORTGAGE", "OR", 46 ...

# %%
kf = pd.read_csv('KeywordsRem.csv') 

# # Get the list of values
values = kf['Keywords'].tolist()
values


df = pd.read_csv('Bay_county_FL_5-(8-vals).csv')

ar = ['BANK', 'VETERANS', 'Lending']

# df = df[df['Grantee'].str.contains('|'.join(ar))==False]
df = df[df['Grantee'].str.contains('|'.join(values))==False]
# df

from itables import show

show(df , paging=True)
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="3d8b2065-a309-4cab-9bdb-410d3d722729" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Status</th>
#       <th>Grantor</th>
#       <th>Grantee</th>
#       <th>Record Date</th>
#       <th>Doc Type</th>
#       <th>Book Type</th>
#       <th>Book</th>
#       <th>Page</th>
#       <th>Clerk File #</th>
#       <th>Legal</th>
#       <th>DocLinks</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [];
#
#     // Define the dt_args
#     let dt_args = {"paging": true, "order": [], "dom": "t"};
#     dt_args["data"] = data;
#
#     $(document).ready(function () {
#
#         $('#3d8b2065-a309-4cab-9bdb-410d3d722729').DataTable(dt_args);
#     });
# </script>
# </div>
